# %%
n=int(input("Nhap 1 so nguyen:"))
if n%2==0:
    print(n,'la so chan')
else:
    print(n,'la so lẻ')
# Out:
# -3 la so lẻ

# %%
n=int(input("Nhập vào số nguyên bất kì:"))
if abs(n)%10==5:
    print(n,"có chữ số tận cùng là 5")
else:
    print(n,"không là số có chữ số tận cùng là 5")
# Out:
# -15 có chữ số tận cùng là 5

# %%
n=int(input())
if n%3==0 and n%5==0:
    print("True")
else:
    print("False")
# Out:
# True

# %%
n=int(input("Nhập năm sinh của bạn:"))
if n<=2007:
    print("bạn đủ điều kiện  để đi bầu cử")
else:
    print("bạn chưa đủ điều kiện để đi bầu cử")
# Out:
# bạn chưa đủ điều kiện để đi bầu cử

# %%
a=float(input())
b=float(input())
if a>b :
    print(a,"là số lớn hơn")
elif a<b:
    print(b,"là số lớn hơn")
else:
    print(a ,"và", b ,"bằng nhau")
# Out:
# 6.0 là số lớn hơn

# %%
x=input("Nhập vào một ký tự:")
if len(x)==1:
    if x.isdigit():
        print(x,"là ki tu so")
    elif x.isalpha():
        print(x,"là ki tu chữ")
    else:
        print(x,"không là ki tu số hay chữ")
else:
    print("vui long nhap 1 ki tu")
# Out:
# vui long nhap 1 ki tu

# %%
n=int(input("Nhap vao diem hoc luc:"))
if n>=8:
    print("Học sinh giỏi")
elif 6.5<=n<8:
    print("học sinh khá")
elif 5<=n<6.5:
    print("hoc sinh trung binh")
else :
    print("hoc sinh kem")
# Out:
# Học sinh giỏi

# %%
n=int(input("Nhap vao 1 nam bat ki:"))
if (n%400==0) or (n%4==0 and n%100!=0):
    print("la nam nhuan")
else:
    print("khong la nam nhuan")
# Out:
# khong la nam nhuan

# %%
n=int(input("Nhập vào một số nguyên từ 0 den 9"))
if n==0:
    print("Khong")
elif n==1:
    print("Mot")
elif n==2:
    print("Hai")
elif n==3:
    print("Ba")
elif n==4:
    print("Bôn")
elif n==5:
    print("Năm")
elif n==6:
    print("Sáu")
elif n==7:
    print("Bảy")
elif n==8:
    print("Tám")
elif n==9:
    print("Chín")
else:
    print("Muoi")
# Out:
# Năm

# %%
n=int(input("Nhap diem thi:"))
if n>=4:
    print("Qua môn")
else:
    print("Hoc lại")
# Out:
# Qua môn

# %%
n=int(input("Nhap nam sinh cua ban:"))
if 0<n<2025:
    s=2025-n
    print("Tuoi hien tai cua ban la:",s)
    if s>18:
        print('ban tren 18 tuoi')
    elif s==18:
        print('ban du 18 tuoi')
    else: 
        print('ban ko du 18 tuoi')

else:
    print("Vui long nhap nam sinh chinh xac")
# Out:
# Vui long nhap nam sinh chinh xac
